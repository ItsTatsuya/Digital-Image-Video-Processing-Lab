# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the input image
image_path = '../../input.jpg'
original_image = cv2.imread(image_path)

# Check if image loaded successfully
if original_image is None:
    print("Error: Could not load image from", image_path)
else:
    print("Image loaded successfully. Shape:", original_image.shape)
# Out:
# Image loaded successfully. Shape: (408, 612, 3)

# %%
# Apply linear spatial filter for smoothing (Mean filter)
kernel_size = (5, 5)
smoothed_image = cv2.blur(original_image, kernel_size)

print("Smoothing applied with kernel size:", kernel_size)
# Out:
# Smoothing applied with kernel size: (5, 5)

# %%
# Convert BGR to RGB for display
original_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
smoothed_rgb = cv2.cvtColor(smoothed_image, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(original_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(smoothed_rgb)
plt.title('Smoothed Image (Mean Filter 5x5)')
plt.axis('off')

plt.show()

# %%
# Save the smoothed image
output_path = 'smoothed_image.jpg'
cv2.imwrite(output_path, smoothed_image)
print("Smoothed image saved as:", output_path)
# Out:
# Smoothed image saved as: smoothed_image.jpg
